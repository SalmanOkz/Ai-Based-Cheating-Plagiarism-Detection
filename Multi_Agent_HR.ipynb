# %% [markdown]
# <a href="https://colab.research.google.com/github/SalmanOkz/Ai-Based-Cheating-Plagiarism-Detection/blob/main/Multi_Agent_HR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -r requirements.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 37.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 99.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.5/395.5 kB 26.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.4/202.4 kB 14.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.9/19.9 MB 74.0 MB/s eta 0:00:00
# ...

# %%
import os
from google.colab import userdata

# Retrieve the Grok API key from Colab secrets
GROK_API_KEY = userdata.get('GROK_API_KEY')

# Set the API key as an environment variable so your application can access it
os.environ['GROK_API_KEY'] = GROK_API_KEY

print("Grok API Key retrieved and set as environment variable. Please re-run your main.py and app.py files.")
# Out:
# Grok API Key retrieved and set as environment variable. Please re-run your main.py and app.py files.

# %%
# !streamlit run app.py
# Out:
# ...
#
# 2026-09-20 09:08:25.163 Uvicorn server started on :::8501
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.53.87.163:8501
#
#   Stopping...
#   Stopping...

# %%
# Install ngrok if you haven't already
# !pip install -q pyngrok

# %% [markdown]
# You will need an `ngrok` authentication token. If you don't have one, you can get it from [ngrok's website](https://dashboard.ngrok.com/get-started/your-authtoken). Add it to Colab's Secrets Manager as `NGROK_AUTH_TOKEN`.

# %%
from pyngrok import ngrok
from google.colab import userdata

# Get ngrok authentication token from Colab secrets
NGROK_AUTH_TOKEN = userdata.get('NGROK_AUTH_TOKEN')

# Authenticate ngrok
ngrok.set_auth_token(NGROK_AUTH_TOKEN)

# Open a tunnel to the Streamlit app's default port (8501)
public_url = ngrok.connect(8501)
print(f"Your Streamlit app is accessible at: {public_url}")
# Out:
# Your Streamlit app is accessible at: NgrokTunnel: "https://cane-sculpture-untying.ngrok-free.dev" -> "http://localhost:8501"

# %%
# %run main.py
# Out:
# Recruitment failed (ValueError). Check input, API key and API quota.

# %%
from google.colab import userdata
userdata.get('NGROK_AUTH_TOKEN')
# Out:
# '3JaP3xFl5RkJoZFCMMT6Cpv5GBB_5oNaYpfxVBBB5CuBqdZ86'
